# %%
message = "Hello python world"
print(message)
# Out:
# Hello python world

# %%
import math


m_c = .3
print("moisture content of the sample is", math.pi * m_c)
# Out:
# moisture content of the sample is 0.9424777960769379

# %%
7+5000+657+7585+842+0000+0
# Out:
# 14091

# %%
a=3
b=7
c=a+b
d=c*2
e=d**5
print(a, b, c, d, e)
# Out:
# 3 7 10 20 3200000
